# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %%
#series and dataframe
df= pd.read_csv(r"C:\Users\betya\OneDrive\Desktop\1ML\week4\data (1).csv")
df.head(100)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 169 entries, 0 to 168
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  169 non-null    int64
#  1   Pulse     169 non-null    int64
#  2   Maxpulse  169 non-null    int64
#  3   Calories  164 non-null    float64
# dtypes: float64(1), int64(3)
# memory usage: 5.4 KB

# %%
df.shape[0] #number of rows
df.describe() #statistical summary
# Out:
#          Duration       Pulse    Maxpulse     Calories
# count  169.000000  169.000000  169.000000   164.000000
# mean    63.846154  107.461538  134.047337   375.790244
# std     42.299949   14.510259   16.450434   266.379919
# min     15.000000   80.000000  100.000000    50.300000
# 25%     45.000000  100.000000  124.000000   250.925000
# 50%     60.000000  105.000000  131.000000   318.600000
# 75%     60.000000  111.000000  141.000000   387.600000
# max    300.000000  159.000000  184.000000  1860.400000

# %%
df.isnull().sum() #checking missing values
# Out:
# Duration    0
# Pulse       0
# Maxpulse    0
# Calories    5
# dtype: int64

# %%
df= df.dropna(subset=['Calories']) #dropping missing values the thing inside the parentheses is optional is a subset of rows or columns to drop
df.isnull().sum()
df.shape
# Out:
# (164, 4)

# %%
df.duplicated().sum()
# Out:
# np.int64(7)

# %%
#handling duplicates
duplicate_rows= df[df.duplicated(keep=False)]
duplicate_rows
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 5          60    102       127     300.0
# 16         60    100       120     300.0
# 31         45     90       112     180.1
# 36         60    102       127     300.0
# 37         60    100       120     300.0
# 38         60    100       120     300.0
# 40         45     90       112     180.1
# 46         60    109       153     387.6
# 71         60    109       153     387.6
# 84         45    100       120     225.3
# 113        45    100       120     225.3
# 124        60    111       151     368.5
# 155        60    111       151     368.5

# %%
df= df.drop_duplicates()
df
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [157 rows x 4 columns]

# %%
#outline detection 
df.describe()
# Out:
#          Duration       Pulse    Maxpulse     Calories
# count  157.000000  157.000000  157.000000   157.000000
# mean    64.522293  107.942675  134.509554   379.414650
# std     43.778959   14.845029   16.607311   271.342426
# min     15.000000   80.000000  100.000000    50.300000
# 25%     45.000000  100.000000  124.000000   251.000000
# 50%     60.000000  106.000000  131.000000   320.400000
# 75%     60.000000  112.000000  143.000000   390.000000
# max    300.000000  159.000000  184.000000  1860.400000

# %%
plt.scatter(df['Duration'], df['Calories'])
plt.show()

# %%
df= df[df['Duration']  < 192]
df.shape
# Out:
# (153, 4)

# %%
plt.scatter(df['Duration'], df['Calories'])
plt.show()
