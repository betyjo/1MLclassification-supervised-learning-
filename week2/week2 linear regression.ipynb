# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# %%
df = pd.read_csv(r"C:\Users\betya\OneDrive\Desktop\salaries.csv")
df.head(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df = pd.read_csv(r"C:\Users\betya\OneDrive\Desktop\salaries.csv")
#       2 df.head(10)
#
# NameError: name 'pd' is not defined

# %%
X = df[['years_of_experience']]
Y = df['salary']

# %%
plt.scatter(X, Y)
plt.xlabel("Year's of experience")
plt.ylabel("Salary")
plt.title("Salary by year's of experience")
# Out:
# Text(0.5, 1.0, "Salary by year's of experience")

# %%
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size = 0.2, random_state=None)
x_test.shape
# Out:
# (20, 1)

# %%
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
model.predict([[7], [5], [3.5]])
# Out:
# C:\Users\betya\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([3597.99419932, 3205.6145873 , 2911.32987828])

# %%
y_pred = model.predict(x_test)
y_pred
# Out:
# array([3205.6145873 , 2617.04516927, 3009.42478129, 2617.04516927,
#        2420.85536326, 3794.18400533, 3794.18400533, 2420.85536326,
#        3009.42478129, 2617.04516927, 3794.18400533, 3794.18400533,
#        2420.85536326, 3401.80439331, 3597.99419932, 3009.42478129,
#        3401.80439331, 2617.04516927, 3009.42478129, 2617.04516927])

# %%
error = y_pred - y_test.values
error
# Out:
# array([ 156.6145873 , -144.95483073,  260.42478129,  116.04516927,
#         183.85536326,  -50.81599467, -145.81599467,  -58.14463674,
#        -205.57521871,  120.04516927,  377.18400533,  437.18400533,
#          31.85536326,  -81.19560669,  155.99419932,  208.42478129,
#         132.80439331,  129.04516927,   18.42478129, -223.95483073])

# %%
plt.scatter(x_test, y_test)
plt.plot(x_test, y_pred, color = 'green')
plt.show()

# %%
r2 = r2_score(y_test, y_pred)
r2
# Out:
# 0.8402818458108207
